# %%
# !pip install gradio pandas numpy matplotlib scikit-learn statsmodels keras prophet
# Out:
# Requirement already satisfied: gradio in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (5.8.0)
# Requirement already satisfied: pandas in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (2.0.2)
# Requirement already satisfied: matplotlib in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (3.9.3)
# Requirement already satisfied: scikit-learn in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (1.6.0)
# Requirement already satisfied: statsmodels in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (0.14.4)
# Requirement already satisfied: keras in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (3.7.0)
# Requirement already satisfied: prophet in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (1.1.6)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (4.7.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.115.6)
# Requirement already satisfied: ffmpy in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.4.0)
# Requirement already satisfied: gradio-client==1.5.1 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (1.5.1)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.25.1 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.26.5)
# Requirement already satisfied: jinja2<4.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (2.1.5)
# Requirement already satisfied: orjson~=3.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (3.10.12)
# Requirement already satisfied: packaging in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (24.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (10.4.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (2.10.3)
# Requirement already satisfied: pydub in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.0.19)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.8.2)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.41.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.15.1)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.32.1)
# Requirement already satisfied: fsspec in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio-client==1.5.1->gradio) (2024.10.0)
# Requirement already satisfied: websockets<15.0,>=10.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from gradio-client==1.5.1->gradio) (14.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: absl-py in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from keras) (2.1.0)
# Requirement already satisfied: rich in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from keras) (3.12.1)
# Requirement already satisfied: optree in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from keras) (0.13.1)
# Requirement already satisfied: ml-dtypes in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from keras) (0.4.1)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from prophet) (1.2.5)
# Requirement already satisfied: holidays<1,>=0.25 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from prophet) (0.62)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib-resources in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from prophet) (6.4.5)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.2.2)
# Requirement already satisfied: idna>=2.8 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: certifi in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.24.1->gradio) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (3.16.1)
# Requirement already satisfied: requests in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (2.32.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=2.0->gradio) (2.27.1)
# Requirement already satisfied: six>=1.5 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from requests->huggingface-hub>=0.25.1->gradio) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\csi\appdata\local\programs\python\python310\lib\site-packages (from requests->huggingface-hub>=0.25.1->gradio) (2.2.3)

# %%
import gradio as gr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
from statsmodels.tsa.arima.model import ARIMA
from keras.models import Sequential
from keras.layers import LSTM, Dense
from prophet import Prophet
import time
import traceback
import sklearn
print(sklearn.__version__)
# Out:
# 1.6.0

# %%
# ARIMA Forecast
def forecast_arima(data, periods, p=1, d=1, q=1):
    try:
        model = ARIMA(data, order=(p, d, q))
        fitted_model = model.fit()
        forecast = fitted_model.forecast(steps=periods)
        return forecast
    except Exception as e:
        print(f"ARIMA Error: {e}")
        return np.zeros(periods)

# LSTM Forecast
def forecast_lstm(data, periods, neurons=50, epochs=10):
    try:
        data = data.values.reshape(-1, 1)
        model = Sequential()
        model.add(LSTM(neurons, activation='relu', input_shape=(1, 1)))
        model.add(Dense(1))
        model.compile(optimizer='adam', loss='mse')
        model.fit(data[:-periods], data[:-periods], epochs=epochs, verbose=0)
        forecast = model.predict(data[-periods:].reshape(periods, 1, 1))
        return forecast.flatten()
    except Exception as e:
        print(f"LSTM Error: {e}")
        return np.zeros(periods)

# Prophet Forecast
def forecast_prophet(data, periods, seasonality="auto"):
    try:
        df = pd.DataFrame({'ds': data.index, 'y': data.values})
        model = Prophet(yearly_seasonality=seasonality)
        model.fit(df)
        future = model.make_future_dataframe(periods=periods)
        forecast = model.predict(future)
        return forecast['yhat'].values[-periods:]
    except Exception as e:
        print(f"Prophet Error: {e}")
        return np.zeros(periods)

# Hybrid Model Forecast
def forecast_hybrid(data, periods, arima_params=(1, 1, 1), lstm_params=(50, 10), seasonality="auto"):
    try:
        arima_forecast = forecast_arima(data, periods, *arima_params)
        lstm_forecast = forecast_lstm(data, periods, neurons=lstm_params[0], epochs=lstm_params[1])
        prophet_forecast = forecast_prophet(data, periods, seasonality=seasonality)
        return (arima_forecast + lstm_forecast + prophet_forecast) / 3
    except Exception as e:
        print(f"Hybrid Error: {e}")
        return np.zeros(periods)

# %%
# Validate and parse CSV
def validate_csv(data):
    try:
        if data.shape[1] < 2:
            return False, "CSV must have at least two columns: Date and Value."
        
        # Attempt to parse the date column with the correct format
        pd.to_datetime(data.iloc[:, 0], dayfirst=True)  # This ensures 'day-first' format
        if not pd.api.types.is_numeric_dtype(data.iloc[:, 1]):
            return False, "Second column must contain numeric values."
        
        return True, None
    except Exception as e:
        return False, f"CSV Validation Error: {e}"

# %%
def mape(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / (y_true + 1e-10))) * 100

def smape(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    denominator = (np.abs(y_true) + np.abs(y_pred)) / 2.0
    return np.mean(np.abs(y_true - y_pred) / (denominator + 1e-10)) * 100

# %%
def run_forecasting(domain, file, model_types, time_frequency, graph_type, p, d, q, neurons, epochs, seasonality):
    try:
        # Read the CSV file
        data = pd.read_csv(file.name)
        
        # Check for required columns
        if 'Date' not in data.columns or 'Value' not in data.columns:
            return "CSV file must contain 'Date' and 'Value' columns.", None, None, None, None
        
        # Validate date column and handle invalid date format
        data.columns = ["Date", "Value"]
        data["Date"] = pd.to_datetime(data["Date"], errors='coerce')
        if data["Date"].isna().any():
            return "Some dates are invalid. Please check the 'Date' column.", None, None, None, None
        
        data.set_index("Date", inplace=True)

        # Period mapping based on frequency
        periods_map = {
            "Monthly": (12, 'M'), "Yearly": (12, 'M'),
            "Quarterly": (4, 'Q'), "Daily": (30, 'D'),
            "Hourly": (24, 'H'), "Minute-wise": (60, 'T'),
            "Second-wise": (60, 'S'), "Weekly": (52, 'W')
        }

        forecast_periods, freq = periods_map.get(time_frequency, (30, 'D'))

        # Dictionary for storing results
        times = {}
        forecasts = {}
        metrics = {}

        # Loop through each model type
        for model_type in model_types:
            start_time = time.time()

            # Forecasting based on model type
            if model_type == 'ARIMA':
                forecast = forecast_arima(data['Value'], forecast_periods, p, d, q)
            elif model_type == 'LSTM':
                forecast = forecast_lstm(data['Value'], forecast_periods, neurons=neurons, epochs=epochs)
            elif model_type == 'PROPHET':
                forecast = forecast_prophet(data['Value'], forecast_periods, seasonality=seasonality)
            elif model_type == 'HYBRID':
                forecast = forecast_hybrid(data['Value'], forecast_periods, (p, d, q), (neurons, epochs), seasonality)

            # Calculate performance metrics
            true_values = data['Value'][-forecast_periods:].values if len(data) > forecast_periods else np.zeros(forecast_periods)
            mae = mean_absolute_error(true_values, forecast)
            rmse = np.sqrt(mean_squared_error(true_values, forecast))
            mape_value = mape(true_values, forecast)
            smape_value = smape(true_values, forecast)

            forecasts[model_type] = forecast
            metrics[model_type] = {"MAE": mae, "RMSE": rmse, "MAPE": mape_value, "SMAPE": smape_value}
            times[model_type] = time.time() - start_time

        # Create a metrics DataFrame
        metrics_df = pd.DataFrame({
            "Model": list(metrics.keys()),
            "MAE": [metrics[m]["MAE"] for m in metrics],
            "RMSE": [metrics[m]["RMSE"] for m in metrics],
            "MAPE": [metrics[m]["MAPE"] for m in metrics],
            "SMAPE": [metrics[m]["SMAPE"] for m in metrics]
        })

        # Identify the best model based on MAE
        best_model = min(metrics, key=lambda x: metrics[x]["MAE"])

        # Generate forecast dates
        forecast_dates = pd.date_range(data.index[-1], periods=forecast_periods, freq=freq)

        # Plot the forecast results
        plt.figure(figsize=(12, 6))
        if graph_type == "Line":
            plt.plot(data.index, data['Value'], label='Historical Data', color='blue', marker='o')
            for model_type, forecast in forecasts.items():
                plt.plot(forecast_dates, forecast, label=f'{model_type} Forecast')
        elif graph_type == "Bar":
            for i, (model_type, forecast) in enumerate(forecasts.items()):
                plt.bar(forecast_dates + pd.Timedelta(days=i), forecast, width=0.2, label=f'{model_type} Forecast')
        elif graph_type == "Histogram":
            plt.hist(data['Value'], bins=20, alpha=0.7, label='Historical Data')
            for model_type, forecast in forecasts.items():
                plt.hist(forecast, bins=20, alpha=0.7, label=f'{model_type} Forecast')
        elif graph_type == "Scatter":
            plt.scatter(data.index, data['Value'], label='Historical Data', color='blue')
            for model_type, forecast in forecasts.items():
                plt.scatter(forecast_dates, forecast, label=f'{model_type} Forecast')

        plt.xlabel('Date')
        plt.ylabel('Value')
        plt.title(f"{domain} Forecast ({time_frequency})")
        plt.legend()
        plt.grid(True)
        
        # Save plot with a dynamic filename
        plot_filename = f"forecast_plot_{time.time()}.png"
        plt.savefig(plot_filename)
        plt.close()

        # Prepare forecast table
        forecast_table = pd.DataFrame({
            "Date": forecast_dates,
            **{model_type: forecasts[model_type] for model_type in forecasts}
        })

        # Time taken DataFrame
        time_df = pd.DataFrame(times.items(), columns=['Model', 'Time Taken (s)'])
        comment = f"The best-performing model based on MAE is: {best_model}."

        return comment, plot_filename, metrics_df, time_df, forecast_table

    except Exception as e:
        print(traceback.format_exc())
        return f"An error occurred: {str(e)}", None, None, None, None

# %%
interface = gr.Interface(
    fn=run_forecasting,
    inputs=[
        gr.Dropdown(choices=["Finance", "Weather", "Healthcare", "Retail Sales", "Traffic", "Crime", "Energy"], label="Select Domain"),
        gr.File(label="Upload CSV"),
        gr.CheckboxGroup(choices=["ARIMA", "LSTM", "PROPHET", "HYBRID"], label="Select Forecasting Models"),
        gr.Radio(choices=["Monthly", "Yearly", "Quarterly", "Daily", "Hourly", "Minute-wise", "Second-wise", "Weekly"], label="Select Time Frequency"),
        gr.Radio(choices=["Line", "Bar", "Histogram", "Scatter"], label="Select Graph Type"),
        gr.Slider(0, 5, value=1, step=1, label="ARIMA (p)"),
        gr.Slider(0, 2, value=1, step=1, label="ARIMA (d)"),
        gr.Slider(0, 5, value=1, step=1, label="ARIMA (q)"),
        gr.Slider(10, 100, value=50, step=10, label="LSTM Neurons"),
        gr.Slider(1, 50, value=10, step=1, label="LSTM Epochs"),
        gr.Dropdown(choices=["auto", "additive", "multiplicative"], label="Prophet Seasonality")
    ],
    outputs=[
        gr.Text(label="Best Model Comment"),
        gr.Image(label="Forecast Graph"),
        gr.Dataframe(label="Metrics Table"),
        gr.Dataframe(label="Time Taken Table"),
        gr.Dataframe(label="Forecast Data Table")
    ],
    title="Time Series Forecasting App",
    description="Upload your data to compare forecasting models and visualize results."
)

interface.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
